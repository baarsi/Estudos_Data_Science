# %%
# importando pandas e usando pd como alias
import pandas as pd

# %%
# dados é um Dataframe
dados = pd.read_csv("datasus_ano_mes_atendimento.csv", encoding="ISO-8859-1", sep=";", skiprows=3, skipfooter=12, thousands=".", decimal=",")
# Out:
# <ipython-input-17-41e42e99fbd7>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("datasus_ano_mes_atendimento.csv", encoding="ISO-8859-1", sep=";", skiprows=3, skipfooter=12, thousands=".", decimal=",")

# %%
# utilizando o método '.head()' para exibir as 5 primeiras linhas do Dataframe dados
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2023/Dez     2024/Jan     2024/Fev  \
# 0        -        -        -  ...  11944255.06  11713667.81  11439176.48
# 1        -        -        -  ...   4279531.59   4404809.58   4492196.94
# 2        -        -        -  ...  18624814.74  21782845.52  19112100.43
# 3        -        -        -  ...   3279093.69   3046959.86   3096827.52
# 4        -        -        -  ...  50786654.84  52704888.70  51281721.02
#
# ...

# %%
# utilizando o método '.head()' para exibir as 5 últimas linhas do Dataframe dados
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...      2023/Dez      2024/Jan  \
# 22        -        -        -        -  ...  1.117256e+08  1.207638e+08
# 23        -        -        -        -  ...  2.564809e+07  2.699545e+07
# 24        -        -        -        -  ...  2.225596e+07  2.289362e+07
# 25        -        -        -        -  ...  4.780130e+07  5.057052e+07
# 26        -        -        -        -  ...  2.849657e+07  3.265231e+07
#
#         2024/Fev      2024/Mar      2024/Abr      2024/Mai      2024/Jun  \
# ...

# %%
# dados2 é outro Dataframe
dados2 = pd.read_csv("datasus_ano_mes_processamento.csv", encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# <ipython-input-20-996c1ec01d7b>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados2 = pd.read_csv("datasus_ano_mes_processamento.csv", encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")

# %%
# utilizando o método '.head()' para exibir as 5 primeiras linhas do Dataframe dados2
dados2.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2023/Dez     2024/Jan     2024/Fev     2024/Mar     2024/Abr  \
# ...

# %%
# utilizando o método '.head()' para exibir as 5 últimas linhas do Dataframe dados2
dados2.tail()
# Out:
#      Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 22   43 Rio Grande do Sul  30931325.46  57363420.01  51547794.07  56673338.49
# 23  50 Mato Grosso do Sul   5377392.11   7002472.61   8423933.19   8797487.68
# 24         51 Mato Grosso   4795299.01   8684882.23   7886243.14   8794109.79
# 25               52 Goiás  15310637.29  22258668.68  21442515.75  20921212.45
# 26    53 Distrito Federal   4745919.19   7632480.67   9647203.26  11098732.99
#
#        2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 22  48397733.07  52413429.62  56636376.98  56113054.70  55356224.30  ...
# 23   9770421.80  10905392.18  10249299.82   9671553.45  10218511.05  ...
# 24   9231645.40  10221763.77   9163314.28   9243148.81   9052354.89  ...
# 25  21615970.67  18270043.87  20540517.13  20650730.67  20868443.56  ...
# 26  12891719.72  12850125.67  12565646.74  13710857.89  13165106.20  ...
#
# ...

# %%
# Média dos dados numéricos do Dataframe dados
dados.mean(numeric_only=True)
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2024/Mai    7.241331e+07
# 2024/Jun    6.438812e+07
# 2024/Jul    5.695299e+07
# 2024/Ago    3.054594e+07
# Total       9.088244e+09
# Length: 206, dtype: float64

# %%
# Visão geral de como o Dataframe dados funciona
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 328 entries, Unidade da Federação to Total
# dtypes: float64(206), object(122)
# memory usage: 69.3+ KB

# %%
# Média dos dados numéricos do Dataframe dados 2
dados2.mean(numeric_only=True)
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2024/Mai    7.319611e+07
# 2024/Jun    7.251213e+07
# 2024/Jul    7.558435e+07
# 2024/Ago    7.533484e+07
# Total       9.088252e+09
# Length: 200, dtype: float64

# %%
# Visão geral de como o Dataframe dados2 funciona
dados2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 202 entries, Unidade da Federação to Total
# dtypes: float64(200), object(2)
# memory usage: 42.7+ KB

# %%
# Ajuste na formatação padrão de python
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean(numeric_only=True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2024/Mai     72413313.83
# 2024/Jun     64388119.10
# 2024/Jul     56952988.52
# 2024/Ago     30545937.91
# Total      9088244246.01
# Length: 206, dtype: float64

# %%
dados2.mean(numeric_only=True)
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2024/Mai     73196107.94
# 2024/Jun     72512132.11
# 2024/Jul     75584351.56
# 2024/Ago     75334843.50
# Total      9088251592.29
# Length: 200, dtype: float64

# %%
# Selecionando apenas a primeira e última colunas (dados) - desafio Aula 1
dados.iloc[:,[0,-1]].head()
# Out:
#   Unidade da Federação         Total
# 0          11 Rondônia 1488884393.98
# 1              12 Acre  626595571.45
# 2          13 Amazonas 2772327408.24
# 3           14 Roraima  475506983.71
# 4              15 Pará 6699094107.75

# %%
# Selecionando apenas a primeira e última colunas (dados2) - desafio Aula 1
dados2.iloc[:,[0,-1]].head()
# Out:
#   Unidade da Federação         Total
# 0          11 Rondônia 1488884393.98
# 1              12 Acre  626595571.45
# 2          13 Amazonas 2772327408.24
# 3           14 Roraima  475506983.71
# 4              15 Pará 6699094107.75
